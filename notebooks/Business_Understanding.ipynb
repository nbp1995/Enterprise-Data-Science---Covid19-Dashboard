# %%
# !ls
# Out:
# Business_Understanding.ipynb
# CRISP_DM.png

# %%
import pandas as pd
pd.set_option('display.max_rows',500)

# %% [markdown]
# ![CRISP_DM](CRISP_DM.png )

# %% [markdown]
# # Business Understanding

# %% [markdown]
# We would like to track the corona virus spread across countries and with personal local information
#
# The general information is not so relevant for me and would like to deep dive local development of the spread

# %% [markdown]
# RKI, webscrape (webscraping) https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Fallzahlen.html
# John Hopkins (GITHUB) https://github.com/CSSEGISandData/COVID-19.git
# REST API services to retreive data https://npgeo-corona-npgeo-de.hub.arcgis.com/

# %%
data_path='E:/EDS/Project/ads_covid-19/data/raw/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
pd_raw=pd.read_csv(data_path)

# %%
pd_raw
# Out:
#                        Province/State                    Country/Region  \
# 0                                 NaN                       Afghanistan
# 1                                 NaN                           Albania
# 2                                 NaN                           Algeria
# 3                                 NaN                           Andorra
# 4                                 NaN                            Angola
# 5                                 NaN               Antigua and Barbuda
# 6                                 NaN                         Argentina
# 7                                 NaN                           Armenia
# 8        Australian Capital Territory                         Australia
# 9                     New South Wales                         Australia
# 10                 Northern Territory                         Australia
# 11                         Queensland                         Australia
# ...
